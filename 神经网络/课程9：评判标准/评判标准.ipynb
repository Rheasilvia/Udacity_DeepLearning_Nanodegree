# %% [markdown]
# ## 混淆矩阵
#
# 1000患者，并被正确诊断为患者——真正
# 200人是患者，而被错误诊断为健康——假负
# 800个是健康的，被错误诊断为患者——假正
# 8000个健康，被诊断为健康——真负
#
# ![image.png](attachment:image.png)
#
#
# ## 准确率
# 在所有就诊者中 我们正确分类的是多少？
# $$accuracy = 正确的分类/总个数$$
#
# ## 准确率不适用的场景
# 仅通过准确率评估模型比较棘手
